# %%
src_array = [
    {
        "src" : "bookings"
    },
    {
        "src" : "customers"
    },
    {
        "src" : "airports"
    },
    {
        "src" : "flights"
    }

]

# %%
dbutils.jobs.taskValues.set("output_key", src_array)
